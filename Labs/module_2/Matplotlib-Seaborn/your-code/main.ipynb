# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y, label='linear') 
plt.show()
plt.plot(x,z, label='quadratic')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2)
ax1.plot(x, y,linewidth=6)
ax2.plot(x, z,color='green',linestyle='dashed')

# %%
# Method 3
df=pd.DataFrame()
df['X']=np.arange(0,100)
df['Y']=[x*2 for x in df['X'] ]
df['Z']=[x**2 for x in df['X'] ]
sns.set()
sns.lineplot('X','Y',data=df)
plt.show()
sns.lineplot('X','Z',data=df)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2,figsize=(8.4, 6.8)) # fig size is in inch
fig. tight_layout(pad=3.0) # handle space between graphs
fig.suptitle('Graphs', fontsize=14, fontweight='bold')
ax1.plot(x, y,color='Purple',linewidth=2,linestyle='dashdot')
ax2.plot(x, z,color='green',linestyle='dashed',linewidth=4)
ax1.set_xlabel('x_label')
ax1.set_ylabel('2x')
ax2.set_xlabel('x_label')
ax2.set_ylabel('square')
ax1.set_title('Linear graph')
ax2.set_title('Quadratic graph')
plt.rc("axes", labelweight= 'bold') # change axes labels to bold fontweight

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x1 = np.arange(0,100)
y=x**2
z=np.exp(x)

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(8.4, 6.8)) 
fig. tight_layout(pad=3.0) # handle space between graphs
fig.suptitle('Graphs', fontsize=14, fontweight='bold')

ax1.plot(x,y,x,z)
ax2.plot(x,y,x,z)

ax1.set_xlabel('x_label')
ax1.set_ylabel('y label')

ax2.set_xlabel('x_label')
ax2.set_ylabel('y_label')

ax1.set_title('log scale')
ax2.set_title('normal scale')
plt.rc("axes", labelweight= 'bold') # change axes labels to bold fontweight

ax1.set_yscale('log')
ax1.set_xscale('log')

ax1.legend(['test'],loc="upper right")
ax2.legend(['Normal scale'],loc="upper right")

# how to put 2 legends?

# %%
fig, ax1 = plt.subplots(1,1,figsize=(8.4, 6.8)) 
fig. tight_layout(pad=3.0) # handle space between graphs
fig.suptitle('Graphs', fontsize=14, fontweight='bold')

ax1.plot(x,z,x,y)


ax1.set_xlabel('x_label')
ax1.set_ylabel('Exp(x) ans x**2')

ax1.set_title('Exp & Quadratic')

plt.rc("axes", labelweight= 'bold') # change axes labels to bold fontweight
ax1.set_yscale('log')

ax1.legend(['Exp'],loc="upper right")

#log scale only on one graph??

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv('/Users/sandrine/Desktop/Prework/806_Repo/Labs/module_2/Matplotlib-Seaborn/Fitbit2.csv')
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %%
fitbit.shape
# Out:
# (367, 24)

# %%
fitbit.columns
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
newdf=fitbit.groupby('Months_encoded').agg('median')
newdf.index
newdf.to_csv('/Users/sandrine/Desktop/Prework/806_Repo/Labs/module_2/Matplotlib-Seaborn/Fitbit2_Month_median.csv')
newdf
# Out:
#                 Calorie burned    Steps  Distance  Floors  Minutes Sedentary  \
# Months_encoded
# 1                       3013.0  10366.0     7.920     9.0              671.0
# 2                       2828.5   9235.0     7.260    11.0              724.5
# 3                       2864.0  11122.0     8.660    12.0              638.0
# 4                       3277.5  13846.5    11.560    13.0              674.5
# 5                       2961.0  11998.0     8.910    12.0              684.0
# 6                       3197.0  12935.5    10.425    17.5              673.0
# 7                       3134.0  10644.0     8.660    16.0              683.0
# 8                       3136.0  12213.0     9.070    11.0              562.0
# 9                       2942.0   9343.0     7.645    13.0              662.5
# 10                      2712.0   7865.0     5.910     7.0              643.0
# 11                      2860.0   9453.5     7.435     5.5              630.5
# ...

# %%
plt.scatter(newdf.index,newdf.Steps)

# %%
# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here

# %%
df2=fitbit.groupby('Work_or_Weekend').agg('median')
df2.to_csv('/Users/sandrine/Desktop/Prework/806_Repo/Labs/module_2/Matplotlib-Seaborn/Fitbit2_median_workdays.csv')
df2
# Out:
#                  Calorie burned    Steps  Distance  Floors  Minutes Sedentary  \
# Work_or_Weekend
# 0                        2894.0   9998.0      8.45     3.0              600.0
# 1                        2992.0  10445.5      8.29    13.0              688.0
#
#                  Minutes Lightly Active  Minutes Fairly Active  \
# Work_or_Weekend
# 0                                 272.0                   15.0
# 1                                 214.0                   26.5
#
#                  Minutes Very Active  Activity Calories  MinutesOfSleep  \
# Work_or_Weekend
# 0                               19.0             1573.0           306.0
# 1                               30.0             1543.0           348.0
#
#                  MinutesOfBeingAwake  NumberOfAwakings  LengthOfRestInMinutes  \
# Work_or_Weekend
# 0                               29.0              16.0                  341.0
# 1                               29.0              17.0                  386.5
#
# ...

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
for i in ['Minutes Lightly Active','Minutes Sedentary','Minutes Sedentary']:
    sns.scatterplot('Steps',i,data=fitbit)
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic=pd.read_csv('/Users/sandrine/Desktop/Prework/806_Repo/Labs/module_2/Matplotlib-Seaborn/Titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.Gender.value_counts()
# Out:
# male      843
# female    466
# Name: Gender, dtype: int64

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
[col for col in titanic.columns if titanic[col].dtypes==int or titanic[col].dtypes==float]
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
# CATEGORICAL VARIABLES

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
sns.set_style('white')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.distplot(titanic["Age"] )

# %%
fig, ax = plt.subplots(figsize=(12,6))
titanic["Age"].plot(kind='hist',bins=30)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, ax =plt.subplots(figsize=(12,6))
ax.hist(titanic.Age.values,bins=10)
plt.show()

fig, ax =plt.subplots(figsize=(12,6))
ax.hist(titanic.Age.values,bins=20)
plt.show()
fig, ax =plt.subplots(figsize=(12,6))
ax.hist(titanic.Age.values,bins=50)
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#          75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#          35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#          14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The more bins we use, the more we display the variations.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.distplot(titanic.Age)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name  Gender        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  23.926502
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %%
# Method 1 - matplotlib
fig, ax =plt.subplots(figsize=(12,6))
ax.hist(titanic.Gender)
plt.show()

# %%
# Method 2 - seaborn
fig, ax =plt.subplots(figsize=(12,6))
sns.countplot(titanic.Gender)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
fig, ax =plt.subplots(figsize=(12,6))
sns.countplot(titanic.Pclass)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(titanic.Age)
"""I use Box plot to get the summary statistics."""

# %%
"""
your comments hereTe

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The oldest passenger was 80.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
""" Violin plot"""

g = sns.violinplot(titanic.Age)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic.Age,titanic.Fare)

# %%
# Method 2 - seaborn
sns.scatterplot(titanic.Age,titanic.Fare)

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# comptute the correlation matrix
corr = titanic.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))
mask
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True],
#        [False,  True,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True,  True],
#        [False, False, False, False,  True,  True,  True],
#        [False, False, False, False, False,  True,  True],
#        [False, False, False, False, False, False,  True]])

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
SibSP and Parch, Fare with (survived,Age,SIbSP,Parch)
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot("Pclass", "Age", data=titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col="Gender")
g = g.map(sns.distplot,'Age')
